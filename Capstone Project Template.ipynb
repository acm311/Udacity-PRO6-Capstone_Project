# %% [markdown]
# # Data Engineering Capstone Project - FIFA Players
# ### Data Engineering Capstone Project
#
# #### Project Summary
# Apply concepts and technologies learned during the Data Engineering Nanodegree program.
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
# Do all imports and installs here
import pandas as pd
import numpy as np

# cd /Users/<user_name>/opt/anaconda3/condabin
# ./conda install pyspark
import pyspark
from pyspark.sql.functions import *

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# The goal of the work will be to present a cloud based Data Warehouse, that allows the user to analyse and response questions about the performance of soccer teams and players based on info from sport history and EA Sports videogame.
# In order to familiarize myself with other cloud solutions alternatives, some technologies used will be from Azure Cloud.
#
# #### Datasets
# The data that we are going to work on comes from three differents sources:
#
# * FIFA 20 complete player dataset (https://www.kaggle.com/stefanoleone992/fifa-20-complete-player-dataset)
#
#     - The dataset is compose of six csv files (last 6 versions of the videogame)
#     - Player positions, with the role in the club and in the national team
#     - Player attributes with statistics as Attacking, Skills, Defense, Mentality, GK Skills, etc.
#     - Player personal data like Nationality, Club, DateOfBirth, Wage, Salary, etc.
#
# * The Big Five European soccer leagues data (https://www.kaggle.com/hikne707/big-five-european-soccer-leagues)
#
#     - All game scores of the big five European soccer leagues (England, Germany, Spain, Italy and France) for the 1995/96 to 2019/20 seasons.

# %%
# Read in the data here
df_2015 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_15.csv')

# %%
df_2015.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  overall  potential  \
# 0        169         67    Argentina         FC Barcelona       93         95
# 1        185         80     Portugal          Real Madrid       92         92
# 2        180         80  Netherlands    FC Bayern München       90         90
# 3        195         95       Sweden  Paris Saint-Germain       90         90
# 4        193         92      Germany    FC Bayern München       90         90
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0          0         0               CF           Left
# 1          0         0           LW, LM          Right
# 2          0         0       RM, LM, RW           Left
# 3          0         0               ST          Right
# 4          0         0               GK          Right
#
#    international_reputation  weak_foot  skill_moves      work_rate body_type  \
# 0                         5          3            4     Medium/Low    Normal
# 1                         5          4            5       High/Low    Normal
# 2                         5          2            4       High/Low    Normal
# 3                         5          4            4     Medium/Low    Normal
# 4                         5          4            1  Medium/Medium    Normal
#
#   real_face  release_clause_eur  \
# 0       Yes                 NaN
# 1       Yes                 NaN
# 2       Yes                 NaN
# 3       Yes                 NaN
# 4       Yes                 NaN
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3  #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                NaN            GK
#
#    team_jersey_number loaned_from      joined  contract_valid_until  \
# 0                10.0         NaN  2004-07-01                2018.0
# 1                 7.0         NaN  2009-07-01                2018.0
# 2                10.0         NaN  2009-08-28                2017.0
# 3                10.0         NaN  2012-07-01                2016.0
# 4                 1.0         NaN  2011-07-01                2019.0
#
#   nation_position  nation_jersey_number  pace  shooting  passing  dribbling  \
# 0              CF                  10.0  93.0      89.0     86.0       96.0
# 1              LW                   7.0  93.0      93.0     81.0       91.0
# 2              RS                  11.0  93.0      86.0     83.0       92.0
# 3              ST                  10.0  76.0      91.0     81.0       86.0
# 4              GK                   1.0   NaN       NaN      NaN        NaN
#
#    defending  physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  \
# 0       27.0    63.0        NaN          NaN         NaN          NaN
# 1       32.0    79.0        NaN          NaN         NaN          NaN
# 2       32.0    64.0        NaN          NaN         NaN          NaN
# 3       34.0    86.0        NaN          NaN         NaN          NaN
# 4        NaN     NaN       87.0         85.0        92.0         86.0
#
#    gk_speed  gk_positioning  \
# 0       NaN             NaN
# 1       NaN             NaN
# 2       NaN             NaN
# 3       NaN             NaN
# 4      60.0            90.0
#
#                                        player_traits attacking_crossing  \
# 0  Finesse Shot, Speed Dribbler (CPU AI Only), On...                 84
# 1  Power Free-Kick, Flair, Long Shot Taker (CPU A...                 83
# 2  Diver, Injury Prone, Avoids Using Weaker Foot,...                 80
# 3  Power Free-Kick, Leadership, Flair, Long Shot ...                 76
# 4      GK Up for Corners, GK Long Throw, 1-on-1 Rush                 25
#
#   attacking_finishing attacking_heading_accuracy attacking_short_passing  \
# 0                94-3                         71                      89
# 1                95+3                         86                      82
# 2                85+2                         50                    86+2
# 3                  91                         76                    84-2
# 4                  25                         25                      42
#
#   attacking_volleys skill_dribbling  ... movement_acceleration  \
# 0              85-5            96-1  ...                    96
# 1              87+2            93+3  ...                    91
# 2              86+2              93  ...                    93
# 3              92+3              88  ...                  74+2
# 4                25              25  ...                  58+8
#
#   movement_sprint_speed movement_agility movement_reactions movement_balance  \
# 0                  90+2               94               94-2               95
# 1                    94               93                 90            63-12
# 2                  93+2             93+1               89+2               91
# 3                  77-1               86                 85               41
# 4                  61+7             43+4               89+3               35
#
#   power_shot_power power_jumping power_stamina power_strength  \
# 0             80-1            73          77-1             60
# 1               94            94            89             79
# 2               86            61         78+11             65
# 3               93            72            78             93
# 4               42            78          44+9           83+5
#
#   power_long_shots mentality_aggression mentality_interceptions  \
# 0               88                   48                      22
# 1               93                   63                      24
# 2             90+1                 47+9                    39+1
# 3               88                   84                      20
# 4               25                 29+3                    30+8
#
#   mentality_positioning mentality_vision mentality_penalties  \
# 0                  92-1               90                  76
# 1                  91+2               81                  85
# 2                  89+2             84+2                80+1
# 3                    86             83-1                  91
# 4                    25               20                  37
#
#   mentality_composure defending_marking defending_standing_tackle  \
# 0                 NaN                25                        21
# 1                 NaN                22                        31
# 2                 NaN                29                      26+2
# 3                 NaN                25                      41-8
# 4                 NaN                25                        25
#
#   defending_sliding_tackle  goalkeeping_diving goalkeeping_handling  \
# 0                       20                   6                   11
# 1                       23                   7                   11
# 2                     26+1                  10                    8
# 3                       27                  13                   15
# 4                       25                  87                 85+3
#
#   goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes    ls  \
# 0                  15                      14                    8  89+3
# 1                  15                      14                   11  91+3
# 2                  11                       5                   15  84+3
# 3                  10                       9                   12  87+3
# 4                  92                    90+6                   86   NaN
#
#      st    rs    lw    lf    cf    rf    rw   lam   cam   ram    lm   lcm  \
# 0  89+3  89+3  92+3  90+3  90+3  90+3  92+3  92+3  92+3  92+3  90+3  79+3
# 1  91+3  91+3  89+3  91+3  91+3  91+3  89+3  89+3  89+3  89+3  87+3  77+3
# 2  84+3  84+3  88+3  87+3  87+3  87+3  88+3  88+3  88+3  88+3  87+3  78+3
# 3  87+3  87+3  84+3  86+3  86+3  86+3  84+3  86+3  86+3  86+3  83+3  76+3
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      cm   rcm    rm   lwb   ldm   cdm   rdm   rwb    lb   lcb    cb   rcb  \
# 0  79+3  79+3  90+3  62+3  62+3  62+3  62+3  62+3  54+3  45+3  45+3  45+3
# 1  77+3  77+3  87+3  63+3  63+3  63+3  63+3  63+3  57+3  52+3  52+3  52+3
# 2  78+3  78+3  87+3  64+3  64+3  64+3  64+3  64+3  55+3  46+3  46+3  46+3
# 3  76+3  76+3  83+3  61+3  65+3  65+3  65+3  61+3  56+3  55+3  55+3  55+3
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#      rb
# 0  54+3
# 1  57+3
# 2  55+3
# 3  56+3
# 4   NaN
#
# [5 rows x 104 columns]

# %%
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 12.3+ MB

# %%
list(df_2015.columns)
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking',
#  'defending_standing_tackle',
#  'defending_sliding_tackle',
#  'goalkeeping_diving',
#  'goalkeeping_handling',
#  'goalkeeping_kicking',
#  'goalkeeping_positioning',
#  'goalkeeping_reflexes',
#  'ls',
#  'st',
#  'rs',
#  'lw',
#  'lf',
#  'cf',
#  'rf',
#  'rw',
#  'lam',
#  'cam',
#  'ram',
#  'lm',
#  'lcm',
#  'cm',
#  'rcm',
#  'rm',
#  'lwb',
#  'ldm',
#  'cdm',
#  'rdm',
#  'rwb',
#  'lb',
#  'lcb',
#  'cb',
#  'rcb',
#  'rb']

# %%
# For this first source (compose of 6 csv files in total), we have 104 columns in total, 
# for our porpuses we selected 73 columns in total

columns_names_selected = ['sofifa_id', 'player_url', 'short_name', 'long_name',
            'age', 'dob', 'height_cm', 'weight_kg',
            'nationality', 'club', 'overall', 'potential',
            'value_eur','wage_eur', 'player_positions',
            'preferred_foot', 'international_reputation', 'weak_foot',
            'skill_moves', 'release_clause_eur', 'player_tags', 'team_position',
            'team_jersey_number', 'joined', 'contract_valid_until',
            'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing',
            'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking',
            'gk_reflexes', 'gk_speed', 'gk_positioning', 'attacking_crossing',
            'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing',
            'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy',
            'skill_long_passing', 'skill_ball_control', 'movement_acceleration',
            'movement_sprint_speed', 'movement_agility', 'movement_reactions',
            'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina',
            'power_strength', 'power_long_shots', 'mentality_aggression',
            'mentality_interceptions', 'mentality_positioning', 'mentality_vision',
            'mentality_penalties', 'mentality_composure', 'defending_marking',
            'defending_standing_tackle', 'defending_sliding_tackle', 'goalkeeping_diving',
            'goalkeeping_handling', 'goalkeeping_kicking', 'goalkeeping_positioning',
            'goalkeeping_reflexes']

df_2015 = df_2015[columns_names_selected]
df_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Data columns (total 73 columns):
# sofifa_id                     15465 non-null int64
# player_url                    15465 non-null object
# short_name                    15465 non-null object
# long_name                     15465 non-null object
# age                           15465 non-null int64
# dob                           15465 non-null object
# height_cm                     15465 non-null int64
# weight_kg                     15465 non-null int64
# nationality                   15465 non-null object
# club                          15465 non-null object
# overall                       15465 non-null int64
# potential                     15465 non-null int64
# value_eur                     15465 non-null int64
# wage_eur                      15465 non-null int64
# player_positions              15465 non-null object
# preferred_foot                15465 non-null object
# international_reputation      15465 non-null int64
# weak_foot                     15465 non-null int64
# skill_moves                   15465 non-null int64
# release_clause_eur            0 non-null float64
# player_tags                   1194 non-null object
# team_position                 15233 non-null object
# team_jersey_number            15233 non-null float64
# joined                        14314 non-null object
# contract_valid_until          15226 non-null float64
# nation_position               1056 non-null object
# nation_jersey_number          1056 non-null float64
# pace                          13762 non-null float64
# shooting                      13762 non-null float64
# passing                       13762 non-null float64
# dribbling                     13762 non-null float64
# defending                     13762 non-null float64
# physic                        13762 non-null float64
# gk_diving                     1703 non-null float64
# gk_handling                   1703 non-null float64
# gk_kicking                    1703 non-null float64
# gk_reflexes                   1703 non-null float64
# gk_speed                      1703 non-null float64
# gk_positioning                1703 non-null float64
# attacking_crossing            15465 non-null object
# attacking_finishing           15465 non-null object
# attacking_heading_accuracy    15465 non-null object
# attacking_short_passing       15465 non-null object
# attacking_volleys             15465 non-null object
# skill_dribbling               15465 non-null object
# skill_curve                   15465 non-null object
# skill_fk_accuracy             15465 non-null object
# skill_long_passing            15465 non-null object
# skill_ball_control            15465 non-null object
# movement_acceleration         15465 non-null object
# movement_sprint_speed         15465 non-null object
# movement_agility              15465 non-null object
# movement_reactions            15465 non-null object
# movement_balance              15465 non-null object
# power_shot_power              15465 non-null object
# power_jumping                 15465 non-null object
# power_stamina                 15465 non-null object
# power_strength                15465 non-null object
# power_long_shots              15465 non-null object
# mentality_aggression          15465 non-null object
# mentality_interceptions       15465 non-null object
# mentality_positioning         15465 non-null object
# mentality_vision              15465 non-null object
# mentality_penalties           15465 non-null object
# mentality_composure           0 non-null float64
# defending_marking             15465 non-null object
# defending_standing_tackle     15465 non-null object
# defending_sliding_tackle      15465 non-null object
# goalkeeping_diving            15465 non-null object
# goalkeeping_handling          15465 non-null object
# goalkeeping_kicking           15465 non-null object
# goalkeeping_positioning       15465 non-null object
# goalkeeping_reflexes          15465 non-null object
# dtypes: float64(17), int64(11), object(45)
# memory usage: 8.6+ MB

# %%
# we made the same selection for the other five csv files

df_2016 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_16.csv')
df_2017 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_17.csv')
df_2018 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_18.csv')
df_2019 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_19.csv')
df_2020 = pd.read_csv('sources/fifa-20-complete-player-dataset/players_20.csv')

df_2016 = df_2016[columns_names_selected]
df_2017 = df_2017[columns_names_selected]
df_2018 = df_2018[columns_names_selected]
df_2019 = df_2019[columns_names_selected]
df_2020 = df_2020[columns_names_selected]

# %%
# In order to manage just one dataframe for this source, we concatenate the 6 dataframes

frames = [df_2015, df_2016, df_2017, df_2018, df_2019, df_2020]
df_fifa = pd.concat(frames)

# %%
pd.set_option('display.max_columns', 100)
df_fifa.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 7       7826  https://sofifa.com/player/7826/robin-van-persi...
# 8     121944  https://sofifa.com/player/121944/bastian-schwe...
# 9     156616  https://sofifa.com/player/156616/franck-ribery...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
# 5          L. Suárez             Luis Alberto Suárez Díaz   27  1987-01-24
# 6          E. Hazard                          Eden Hazard   23  1991-01-07
# 7      R. van Persie                     Robin van Persie   30  1983-08-06
# 8  B. Schweinsteiger               Bastian Schweinsteiger   29  1984-08-01
# 9          F. Ribéry                  Franck Bilal Ribéry   31  1983-04-07
#
#    height_cm  weight_kg  nationality                 club  overall  potential  \
# 0        169         67    Argentina         FC Barcelona       93         95
# 1        185         80     Portugal          Real Madrid       92         92
# 2        180         80  Netherlands    FC Bayern München       90         90
# 3        195         95       Sweden  Paris Saint-Germain       90         90
# 4        193         92      Germany    FC Bayern München       90         90
# 5        181         81      Uruguay         FC Barcelona       89         91
# 6        173         74      Belgium              Chelsea       88         90
# 7        187         71  Netherlands    Manchester United       88         88
# 8        183         79      Germany    FC Bayern München       88         88
# 9        170         72       France    FC Bayern München       88         88
#
#    value_eur  wage_eur player_positions preferred_foot  \
# 0          0         0               CF           Left
# 1          0         0           LW, LM          Right
# 2          0         0       RM, LM, RW           Left
# 3          0         0               ST          Right
# 4          0         0               GK          Right
# 5          0         0           ST, CF          Right
# 6          0         0           LM, RM          Right
# 7          0         0               ST           Left
# 8          0         0          CM, CDM          Right
# 9          0         0               LM          Right
#
#    international_reputation  weak_foot  skill_moves  release_clause_eur  \
# 0                         5          3            4                 NaN
# 1                         5          4            5                 NaN
# 2                         5          2            4                 NaN
# 3                         5          4            4                 NaN
# 4                         5          4            1                 NaN
# 5                         5          4            4                 NaN
# 6                         4          4            4                 NaN
# 7                         5          3            4                 NaN
# 8                         4          3            3                 NaN
# 9                         4          4            5                 NaN
#
#                                          player_tags team_position  \
# 0  #Speedster, #Dribbler, #FK Specialist, #Acroba...            CF
# 1  #Speedster, #Dribbler, #Distance Shooter, #Acr...            LW
# 2  #Speedster, #Dribbler, #Distance Shooter, #Acr...           SUB
# 3  #Poacher, #Aerial Threat, #Distance Shooter, #...            ST
# 4                                                NaN            GK
# 5                       #Acrobat, #Clinical Finisher           RES
# 6                    #Speedster, #Dribbler, #Acrobat            LM
# 7              #Distance Shooter, #Clinical Finisher            RS
# 8                 #Playmaker  , #Engine, #Tactician            SUB
# 9                                #Dribbler, #Acrobat           SUB
#
#    team_jersey_number      joined  contract_valid_until nation_position  \
# 0                10.0  2004-07-01                2018.0              CF
# 1                 7.0  2009-07-01                2018.0              LW
# 2                10.0  2009-08-28                2017.0              RS
# 3                10.0  2012-07-01                2016.0              ST
# 4                 1.0  2011-07-01                2019.0              GK
# 5                 9.0  2014-07-11                2019.0             NaN
# 6                10.0  2012-07-01                2017.0              LM
# 7                20.0  2012-08-17                2016.0              LS
# 8                31.0  2002-07-01                2016.0             SUB
# 9                 7.0  2007-07-01                2017.0             NaN
#
#    nation_jersey_number  pace  shooting  passing  dribbling  defending  \
# 0                  10.0  93.0      89.0     86.0       96.0       27.0
# 1                   7.0  93.0      93.0     81.0       91.0       32.0
# 2                  11.0  93.0      86.0     83.0       92.0       32.0
# 3                  10.0  76.0      91.0     81.0       86.0       34.0
# 4                   1.0   NaN       NaN      NaN        NaN        NaN
# 5                   NaN  83.0      87.0     79.0       88.0       42.0
# 6                  10.0  90.0      82.0     84.0       91.0       32.0
# 7                   9.0  74.0      90.0     82.0       83.0       33.0
# 8                   7.0  61.0      81.0     85.0       82.0       78.0
# 9                   NaN  89.0      78.0     85.0       92.0       29.0
#
#    physic  gk_diving  gk_handling  gk_kicking  gk_reflexes  gk_speed  \
# 0    63.0        NaN          NaN         NaN          NaN       NaN
# 1    79.0        NaN          NaN         NaN          NaN       NaN
# 2    64.0        NaN          NaN         NaN          NaN       NaN
# 3    86.0        NaN          NaN         NaN          NaN       NaN
# 4     NaN       87.0         85.0        92.0         86.0      60.0
# 5    79.0        NaN          NaN         NaN          NaN       NaN
# 6    64.0        NaN          NaN         NaN          NaN       NaN
# 7    68.0        NaN          NaN         NaN          NaN       NaN
# 8    80.0        NaN          NaN         NaN          NaN       NaN
# 9    62.0        NaN          NaN         NaN          NaN       NaN
#
#    gk_positioning attacking_crossing attacking_finishing  \
# 0             NaN                 84                94-3
# 1             NaN                 83                95+3
# 2             NaN                 80                85+2
# 3             NaN                 76                  91
# 4            90.0                 25                  25
# 5             NaN                 77                91+2
# 6             NaN               78-4                  83
# 7             NaN                 81                  91
# 8             NaN                 81                76+2
# 9             NaN                 83                  79
#
#   attacking_heading_accuracy attacking_short_passing attacking_volleys  \
# 0                         71                      89              85-5
# 1                         86                      82              87+2
# 2                         50                    86+2              86+2
# 3                         76                    84-2              92+3
# 4                         25                      42                25
# 5                         75                      82                85
# 6                         57                    87+1                79
# 7                         73                      85                92
# 8                       79+1                    88-1              83-1
# 9                         41                      89                81
#
#   skill_dribbling skill_curve skill_fk_accuracy skill_long_passing  \
# 0            96-1        89+2              90+4                 76
# 1            93+3          88                79                 72
# 2              93          85              83-1               76+3
# 3              88          80                80               76+4
# 4              25          25                25                 41
# 5            90-2          86                84                 64
# 6            92+2          82                79                 82
# 7              84          86                81                 75
# 8            81-1        82-1                78                 87
# 9              92        84-2                81               74+2
#
#   skill_ball_control movement_acceleration movement_sprint_speed  \
# 0                 96                    96                  90+2
# 1               92-3                    91                    94
# 2               90+1                    93                  93+2
# 3                 90                  74+2                  77-1
# 4                 31                  58+8                  61+7
# 5                 89                    88                    79
# 6                 89                  93+2                    87
# 7               87-1                  73-1                  74-1
# 8                 86                  58-1                    64
# 9               91-1                  91-1                  87-1
#
#   movement_agility movement_reactions movement_balance power_shot_power  \
# 0               94               94-2               95             80-1
# 1               93                 90            63-12               94
# 2             93+1               89+2               91               86
# 3               86                 85               41               93
# 4             43+4               89+3               35               42
# 5               86               91+2            60-25               84
# 6               92               85+1               90               79
# 7             80-1               88+1               59               90
# 8             74-1                 90             75-1               86
# 9               92               89-1               92               76
#
#   power_jumping power_stamina power_strength power_long_shots  \
# 0            73          77-1             60               88
# 1            94            89             79               93
# 2            61         78+11             65             90+1
# 3            72            78             93               88
# 4            78          44+9           83+5               25
# 5            69            86             76             82-2
# 6            59          74+1             63               82
# 7            59            72             72             86-1
# 8          82+7            86           77+1               86
# 9          51-2            72           62-2             73-1
#
#   mentality_aggression mentality_interceptions mentality_positioning  \
# 0                   48                      22                  92-1
# 1                   63                      24                  91+2
# 2                 47+9                    39+1                  89+2
# 3                   84                      20                    86
# 4                 29+3                    30+8                    25
# 5                   78                      41                  88+2
# 6                   54                      41                    84
# 7                   55                      34                    90
# 8                 80+1                      86                    82
# 9                   52                      36                    83
#
#   mentality_vision mentality_penalties mentality_composure defending_marking  \
# 0               90                  76                 NaN                25
# 1               81                  85                 NaN                22
# 2             84+2                80+1                 NaN                29
# 3             83-1                  91                 NaN                25
# 4               20                  37                 NaN                25
# 5               84                  85                 NaN                30
# 6             86+1                86+1                 NaN                25
# 7               82                  86                 NaN                23
# 8               86                  81                 NaN              69+1
# 9               88                  80                 NaN                25
#
#   defending_standing_tackle defending_sliding_tackle goalkeeping_diving  \
# 0                        21                       20                  6
# 1                        31                       23                  7
# 2                      26+2                     26+1                 10
# 3                      41-8                       27                 13
# 4                        25                       25                 87
# 5                        45                       38                 27
# 6                        27                       22                 11
# 7                        32                       21                  9
# 8                      80+1                       77                 14
# 9                        25                       26                 15
#
#   goalkeeping_handling goalkeeping_kicking goalkeeping_positioning  \
# 0                   11                  15                      14
# 1                   11                  15                      14
# 2                    8                  11                       5
# 3                   15                  10                       9
# 4                 85+3                  92                    90+6
# 5                   25                  31                      33
# 6                   12                   6                       8
# 7                   10                   5                       7
# 8                   14                  13                      13
# 9                    6                   9                       7
#
#   goalkeeping_reflexes
# 0                    8
# 1                   11
# 2                   15
# 3                   12
# 4                   86
# 5                   37
# 6                    8
# 7                    8
# 8                   11
# 9                   10

# %%
# Save locally the concatenated dataframe
df_fifa.to_csv('sources/fifa-20-complete-player-dataset/fifa_players.csv')

# %%
# Load of the European soccer leagues source
df_euro_league = pd.read_csv('sources/BIG FIVE 1995-2019.csv')

# %%
df_euro_league.head()
# Out:
#    Round                     Date                Team 1   FT   HT  \
# 0      1  (Sat) 19 Aug 1995 (W33)       Aston Villa FC   3-1  3-0
# 1      1  (Sat) 19 Aug 1995 (W33)  Blackburn Rovers FC   1-0  1-0
# 2      1  (Sat) 19 Aug 1995 (W33)           Chelsea FC   0-0  0-0
# 3      1  (Sat) 19 Aug 1995 (W33)         Liverpool FC   1-0  0-0
# 4      1  (Sat) 19 Aug 1995 (W33)   Manchester City FC   1-1  0-1
#
#                     Team 2  Year Country  FT Team 1  FT Team 2  HT Team 1  \
# 0    Manchester United FC   1995     ENG          3          1          3
# 1  Queens Park Rangers FC   1995     ENG          1          0          1
# 2              Everton FC   1995     ENG          0          0          0
# 3  Sheffield Wednesday FC   1995     ENG          1          0          0
# 4    Tottenham Hotspur FC   1995     ENG          1          1          0
#
#    HT Team 2  GGD  Team 1 (pts)  Team 2 (pts)
# 0          0    2             3             0
# 1          0    1             3             0
# 2          0    0             1             1
# 3          0    1             3             0
# 4          1    0             1             1

# %%
# Compare teams names between the two sources
df_fifa_teams = df_fifa['club'].unique()
df_fifa_teams = pd.DataFrame(df_fifa_teams)
df_fifa_teams.head(n=20)
# Out:
#                        0
# 0           FC Barcelona
# 1            Real Madrid
# 2      FC Bayern München
# 3    Paris Saint-Germain
# 4                Chelsea
# 5      Manchester United
# 6        Manchester City
# 7      Borussia Dortmund
# 8                Arsenal
# 9               Juventus
# 10     Tottenham Hotspur
# 11       Atlético Madrid
# 12                Napoli
# 13                  Roma
# 14        Galatasaray SK
# 15         FC Schalke 04
# 16            Fiorentina
# 17             Liverpool
# 18  Zenit St. Petersburg
# 19      AS Saint-Étienne

# %%
df_teams_euro = df_euro_league['Team 1'].unique()
df_teams_euro = pd.DataFrame(df_teams_euro)
df_teams_euro.head(n=20)
# Out:
#                           0
# 0           Aston Villa FC
# 1      Blackburn Rovers FC
# 2               Chelsea FC
# 3             Liverpool FC
# 4       Manchester City FC
# 5      Newcastle United FC
# 6           Southampton FC
# 7       West Ham United FC
# 8             Wimbledon FC
# 9               Arsenal FC
# 10         Leeds United FC
# 11     Bolton Wanderers FC
# 12        Coventry City FC
# 13              Everton FC
# 14    Manchester United FC
# 15    Nottingham Forest FC
# 16  Queens Park Rangers FC
# 17  Sheffield Wednesday FC
# 18    Tottenham Hotspur FC
# 19        Middlesbrough FC

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
        .builder \
        .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
        .getOrCreate()

spark_df = spark.read.csv('sources/fifa-20-complete-player-dataset/fifa_players.csv', header='true')
type(spark_df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# In the next step we will focus on standardize the date format, as well the team names

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %% [markdown]
# In the prevous step we selected the columns that are relevant for our porpuses.
# Now we will start checking the missing values.

# %%
#missing values for fifa players data source
for column in df_fifa:
    if df_fifa[column].isnull().any():
        print('{0} has {1} null values'.format(column, df_fifa[column].isnull().sum()))
# Out:
# release_clause_eur has 51644 null values
# player_tags has 92698 null values
# team_position has 1326 null values
# team_jersey_number has 1326 null values
# joined has 8038 null values
# contract_valid_until has 1333 null values
# nation_position has 94470 null values
# nation_jersey_number has 94470 null values
# pace has 11247 null values
# shooting has 11247 null values
# passing has 11247 null values
# dribbling has 11247 null values
# defending has 11247 null values
# physic has 11247 null values
# gk_diving has 89748 null values
# gk_handling has 89748 null values
# gk_kicking has 89748 null values
# gk_reflexes has 89748 null values
# gk_speed has 89748 null values
# gk_positioning has 89748 null values
# mentality_composure has 30346 null values

# %% [markdown]
# Looking the data and the fields involved in null values, we realized that there is no need to replace values, normally are indicator that differences a player and a goalkeeper.

# %%
#missing values for euro league data source
total=0
for column in df_euro_league:
    if df_euro_league[column].isnull().any():
        total+=1
        print('{0} has {1} null values'.format(column, df_euro_league[column].isnull().sum()))
if total==0:
    print('No null values for euro league data source.')
# Out:
# No null values for euro league data source.

# %%
# Check for dupolicate data for fifa players data source
df1 = spark_df.groupBy(columns_names_selected).count().filter("count > 1")
df1.show()
# Out:
# +---------+----------+----------+---------+---+---+---------+---------+-----------+----+-------+---------+---------+--------+----------------+--------------+------------------------+---------+-----------+------------------+-----------+-------------+------------------+------+--------------------+---------------+--------------------+----+--------+-------+---------+---------+------+---------+-----------+----------+-----------+--------+--------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+-----------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+-----+
# |sofifa_id|player_url|short_name|long_name|age|dob|height_cm|weight_kg|nationality|club|overall|potential|value_eur|wage_eur|player_positions|preferred_foot|international_reputation|weak_foot|skill_moves|release_clause_eur|player_tags|team_position|team_jersey_number|joined|contract_valid_until|nation_position|nation_jersey_number|pace|shooting|passing|dribbling|defending|physic|gk_diving|gk_handling|gk_kicking|gk_reflexes|gk_speed|gk_positioning|attacking_crossing|attacking_finishing|attacking_heading_accuracy|attacking_short_passing|attacking_volleys|skill_dribbling|skill_curve|skill_fk_accuracy|skill_long_passing|skill_ball_control|movement_acceleration|movement_sprint_speed|movement_agility|movement_reactions|movement_balance|power_shot_power|power_jumping|power_stamina|power_strength|power_long_shots|mentality_aggression|mentality_interceptions|mentality_positioning|mentality_vision|mentality_penalties|mentality_composure|defending_marking|defending_standing_tackle|defending_sliding_tackle|goalkeeping_diving|goalkeeping_handling|goalkeeping_kicking|goalkeeping_positioning|goalkeeping_reflexes|count|
# +---------+----------+----------+---------+---+---+---------+---------+-----------+----+-------+---------+---------+--------+----------------+--------------+------------------------+---------+-----------+------------------+-----------+-------------+------------------+------+--------------------+---------------+--------------------+----+--------+-------+---------+---------+------+---------+-----------+----------+-----------+--------+--------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+-----------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+-----+
# +---------+----------+----------+---------+---+---+---------+---------+-----------+----+-------+---------+---------+--------+----------------+--------------+------------------------+---------+-----------+------------------+-----------+-------------+------------------+------+--------------------+---------------+--------------------+----+--------+-------+---------+---------+------+---------+-----------+----------+-----------+--------+--------------+------------------+-------------------+--------------------------+-----------------------+-----------------+---------------+-----------+-----------------+------------------+------------------+---------------------+---------------------+----------------+------------------+----------------+----------------+-------------+-------------+--------------+----------------+--------------------+-----------------------+---------------------+----------------+-------------------+-------------------+-----------------+-------------------------+------------------------+------------------+--------------------+-------------------+-----------------------+--------------------+-----+

# %%
# Check for dupolicate data for euro league data source
columns_names = ['Round', 'Date', 'Team 1', 'FT', 'HT', 'Team 2', 'Year', 'Country', 'FT Team 1', 
                 'FT Team 2', 'HT Team 1', 'HT Team 2', 'GGD', 'Team 1 (pts)', 'Team 2 (pts)']
spark_df_euro = spark.read.csv('sources/BIG FIVE 1995-2019.csv', header='true')
df2 = spark_df_euro.groupBy(columns_names).count().filter("count > 1")
df2.show()
# Out:
# +-----+----+------+---+---+------+----+-------+---------+---------+---------+---------+---+------------+------------+-----+
# |Round|Date|Team 1| FT| HT|Team 2|Year|Country|FT Team 1|FT Team 2|HT Team 1|HT Team 2|GGD|Team 1 (pts)|Team 2 (pts)|count|
# +-----+----+------+---+---+------+----+-------+---------+---------+---------+---------+---+------------+------------+-----+
# +-----+----+------+---+---+------+----+-------+---------+---------+---------+---------+---+------------+------------+-----+

# %% [markdown]
# No duplicate data found for the sources

# %%
# Performing cleaning tasks on euro league data source

#Getting info
spark_df_euro = spark.read.csv('sources/BIG FIVE 1995-2019.csv', header='true')
spark_df_euro.createOrReplaceTempView("EURO_LEAGUE")

query = 'SELECT * FROM EURO_LEAGUE'
spark_df = spark.sql(query)
spark_df.limit(20).toPandas().head(n=20)
# Out:
#    Round                     Date                   Team 1   FT   HT  \
# 0      1  (Sat) 19 Aug 1995 (W33)          Aston Villa FC   3-1  3-0
# 1      1  (Sat) 19 Aug 1995 (W33)     Blackburn Rovers FC   1-0  1-0
# 2      1  (Sat) 19 Aug 1995 (W33)              Chelsea FC   0-0  0-0
# 3      1  (Sat) 19 Aug 1995 (W33)            Liverpool FC   1-0  0-0
# 4      1  (Sat) 19 Aug 1995 (W33)      Manchester City FC   1-1  0-1
# 5      1  (Sat) 19 Aug 1995 (W33)     Newcastle United FC   3-0  1-0
# 6      1  (Sat) 19 Aug 1995 (W33)          Southampton FC   3-4  1-3
# 7      1  (Sat) 19 Aug 1995 (W33)      West Ham United FC   1-2  1-0
# 8      1  (Sat) 19 Aug 1995 (W33)            Wimbledon FC   3-2  2-2
# 9      1  (Sun) 20 Aug 1995 (W33)              Arsenal FC   1-1  1-1
# 10     2  (Mon) 21 Aug 1995 (W34)         Leeds United FC   1-0  0-0
# 11     2  (Tue) 22 Aug 1995 (W34)     Bolton Wanderers FC   1-3  0-1
# 12     2  (Wed) 23 Aug 1995 (W34)        Coventry City FC   2-1  1-0
# 13     2  (Wed) 23 Aug 1995 (W34)              Everton FC   0-2  0-0
# 14     2  (Wed) 23 Aug 1995 (W34)    Manchester United FC   2-1  0-0
# 15     2  (Wed) 23 Aug 1995 (W34)    Nottingham Forest FC   0-0  0-0
# 16     2  (Wed) 23 Aug 1995 (W34)  Queens Park Rangers FC   0-3  0-1
# 17     2  (Wed) 23 Aug 1995 (W34)  Sheffield Wednesday FC   2-1  1-0
# 18     2  (Wed) 23 Aug 1995 (W34)    Tottenham Hotspur FC   0-1  0-0
# 19     2  (Sat) 26 Aug 1995 (W34)     Bolton Wanderers FC   2-1  1-0
#
#                      Team 2  Year Country FT Team 1 FT Team 2 HT Team 1  \
# 0     Manchester United FC   1995     ENG         3         1         3
# 1   Queens Park Rangers FC   1995     ENG         1         0         1
# 2               Everton FC   1995     ENG         0         0         0
# 3   Sheffield Wednesday FC   1995     ENG         1         0         0
# 4     Tottenham Hotspur FC   1995     ENG         1         1         0
# 5         Coventry City FC   1995     ENG         3         0         1
# 6     Nottingham Forest FC   1995     ENG         3         4         1
# 7          Leeds United FC   1995     ENG         1         2         1
# 8      Bolton Wanderers FC   1995     ENG         3         2         2
# 9         Middlesbrough FC   1995     ENG         1         1         1
# 10            Liverpool FC   1995     ENG         1         0         0
# 11     Newcastle United FC   1995     ENG         1         3         0
# 12      Manchester City FC   1995     ENG         2         1         1
# 13              Arsenal FC   1995     ENG         0         2         0
# 14      West Ham United FC   1995     ENG         2         1         0
# 15              Chelsea FC   1995     ENG         0         0         0
# 16            Wimbledon FC   1995     ENG         0         3         0
# 17     Blackburn Rovers FC   1995     ENG         2         1         1
# 18          Aston Villa FC   1995     ENG         0         1         0
# 19     Blackburn Rovers FC   1995     ENG         2         1         1
#
#    HT Team 2 GGD Team 1 (pts) Team 2 (pts)
# 0          0   2            3            0
# 1          0   1            3            0
# 2          0   0            1            1
# 3          0   1            3            0
# 4          1   0            1            1
# 5          0   3            3            0
# 6          3   1            0            3
# 7          0   1            0            3
# 8          2   1            3            0
# 9          1   0            1            1
# 10         0   1            3            0
# 11         1   2            0            3
# 12         0   1            3            0
# 13         0   2            0            3
# 14         0   1            3            0
# 15         0   0            1            1
# 16         1   3            0            3
# 17         0   1            3            0
# 18         0   1            0            3
# 19         0   1            3            0

# %%
#Remove the text ' FC' at the end of team names
newDf = spark_df.withColumn('Team 1', regexp_replace('Team 1', ' FC', ''))
newDf = newDf.withColumn('Team 2', regexp_replace('Team 2', ' FC', ''))
newDf.limit(20).toPandas().head(n=20)
# Out:
#    Round                     Date                Team 1   FT   HT  \
# 0      1  (Sat) 19 Aug 1995 (W33)          Aston Villa   3-1  3-0
# 1      1  (Sat) 19 Aug 1995 (W33)     Blackburn Rovers   1-0  1-0
# 2      1  (Sat) 19 Aug 1995 (W33)              Chelsea   0-0  0-0
# 3      1  (Sat) 19 Aug 1995 (W33)            Liverpool   1-0  0-0
# 4      1  (Sat) 19 Aug 1995 (W33)      Manchester City   1-1  0-1
# 5      1  (Sat) 19 Aug 1995 (W33)     Newcastle United   3-0  1-0
# 6      1  (Sat) 19 Aug 1995 (W33)          Southampton   3-4  1-3
# 7      1  (Sat) 19 Aug 1995 (W33)      West Ham United   1-2  1-0
# 8      1  (Sat) 19 Aug 1995 (W33)            Wimbledon   3-2  2-2
# 9      1  (Sun) 20 Aug 1995 (W33)              Arsenal   1-1  1-1
# 10     2  (Mon) 21 Aug 1995 (W34)         Leeds United   1-0  0-0
# 11     2  (Tue) 22 Aug 1995 (W34)     Bolton Wanderers   1-3  0-1
# 12     2  (Wed) 23 Aug 1995 (W34)        Coventry City   2-1  1-0
# 13     2  (Wed) 23 Aug 1995 (W34)              Everton   0-2  0-0
# 14     2  (Wed) 23 Aug 1995 (W34)    Manchester United   2-1  0-0
# 15     2  (Wed) 23 Aug 1995 (W34)    Nottingham Forest   0-0  0-0
# 16     2  (Wed) 23 Aug 1995 (W34)  Queens Park Rangers   0-3  0-1
# 17     2  (Wed) 23 Aug 1995 (W34)  Sheffield Wednesday   2-1  1-0
# 18     2  (Wed) 23 Aug 1995 (W34)    Tottenham Hotspur   0-1  0-0
# 19     2  (Sat) 26 Aug 1995 (W34)     Bolton Wanderers   2-1  1-0
#
#                   Team 2  Year Country FT Team 1 FT Team 2 HT Team 1  \
# 0     Manchester United   1995     ENG         3         1         3
# 1   Queens Park Rangers   1995     ENG         1         0         1
# 2               Everton   1995     ENG         0         0         0
# 3   Sheffield Wednesday   1995     ENG         1         0         0
# 4     Tottenham Hotspur   1995     ENG         1         1         0
# 5         Coventry City   1995     ENG         3         0         1
# 6     Nottingham Forest   1995     ENG         3         4         1
# 7          Leeds United   1995     ENG         1         2         1
# 8      Bolton Wanderers   1995     ENG         3         2         2
# 9         Middlesbrough   1995     ENG         1         1         1
# 10            Liverpool   1995     ENG         1         0         0
# 11     Newcastle United   1995     ENG         1         3         0
# 12      Manchester City   1995     ENG         2         1         1
# 13              Arsenal   1995     ENG         0         2         0
# 14      West Ham United   1995     ENG         2         1         0
# 15              Chelsea   1995     ENG         0         0         0
# 16            Wimbledon   1995     ENG         0         3         0
# 17     Blackburn Rovers   1995     ENG         2         1         1
# 18          Aston Villa   1995     ENG         0         1         0
# 19     Blackburn Rovers   1995     ENG         2         1         1
#
#    HT Team 2 GGD Team 1 (pts) Team 2 (pts)
# 0          0   2            3            0
# 1          0   1            3            0
# 2          0   0            1            1
# 3          0   1            3            0
# 4          1   0            1            1
# 5          0   3            3            0
# 6          3   1            0            3
# 7          0   1            0            3
# 8          2   1            3            0
# 9          1   0            1            1
# 10         0   1            3            0
# 11         1   2            0            3
# 12         0   1            3            0
# 13         0   2            0            3
# 14         0   1            3            0
# 15         0   0            1            1
# 16         1   3            0            3
# 17         0   1            3            0
# 18         0   1            0            3
# 19         0   1            3            0

# %%
#Cleaning date field
newDf = newDf.withColumn("New_Date", lpad(concat(split(newDf['Date'], ' ')[1], 
                                                 lit(' '), split(newDf['Date'], ' ')[2], lit(' '), 
                                                 split(newDf['Date'], ' ')[3]), 11, '0'))

newDf.limit(20).toPandas().head(n=20)
# Out:
#    Round                     Date                Team 1   FT   HT  \
# 0      1  (Sat) 19 Aug 1995 (W33)          Aston Villa   3-1  3-0
# 1      1  (Sat) 19 Aug 1995 (W33)     Blackburn Rovers   1-0  1-0
# 2      1  (Sat) 19 Aug 1995 (W33)              Chelsea   0-0  0-0
# 3      1  (Sat) 19 Aug 1995 (W33)            Liverpool   1-0  0-0
# 4      1  (Sat) 19 Aug 1995 (W33)      Manchester City   1-1  0-1
# 5      1  (Sat) 19 Aug 1995 (W33)     Newcastle United   3-0  1-0
# 6      1  (Sat) 19 Aug 1995 (W33)          Southampton   3-4  1-3
# 7      1  (Sat) 19 Aug 1995 (W33)      West Ham United   1-2  1-0
# 8      1  (Sat) 19 Aug 1995 (W33)            Wimbledon   3-2  2-2
# 9      1  (Sun) 20 Aug 1995 (W33)              Arsenal   1-1  1-1
# 10     2  (Mon) 21 Aug 1995 (W34)         Leeds United   1-0  0-0
# 11     2  (Tue) 22 Aug 1995 (W34)     Bolton Wanderers   1-3  0-1
# 12     2  (Wed) 23 Aug 1995 (W34)        Coventry City   2-1  1-0
# 13     2  (Wed) 23 Aug 1995 (W34)              Everton   0-2  0-0
# 14     2  (Wed) 23 Aug 1995 (W34)    Manchester United   2-1  0-0
# 15     2  (Wed) 23 Aug 1995 (W34)    Nottingham Forest   0-0  0-0
# 16     2  (Wed) 23 Aug 1995 (W34)  Queens Park Rangers   0-3  0-1
# 17     2  (Wed) 23 Aug 1995 (W34)  Sheffield Wednesday   2-1  1-0
# 18     2  (Wed) 23 Aug 1995 (W34)    Tottenham Hotspur   0-1  0-0
# 19     2  (Sat) 26 Aug 1995 (W34)     Bolton Wanderers   2-1  1-0
#
#                   Team 2  Year Country FT Team 1 FT Team 2 HT Team 1  \
# 0     Manchester United   1995     ENG         3         1         3
# 1   Queens Park Rangers   1995     ENG         1         0         1
# 2               Everton   1995     ENG         0         0         0
# 3   Sheffield Wednesday   1995     ENG         1         0         0
# 4     Tottenham Hotspur   1995     ENG         1         1         0
# 5         Coventry City   1995     ENG         3         0         1
# 6     Nottingham Forest   1995     ENG         3         4         1
# 7          Leeds United   1995     ENG         1         2         1
# 8      Bolton Wanderers   1995     ENG         3         2         2
# 9         Middlesbrough   1995     ENG         1         1         1
# 10            Liverpool   1995     ENG         1         0         0
# 11     Newcastle United   1995     ENG         1         3         0
# 12      Manchester City   1995     ENG         2         1         1
# 13              Arsenal   1995     ENG         0         2         0
# 14      West Ham United   1995     ENG         2         1         0
# 15              Chelsea   1995     ENG         0         0         0
# 16            Wimbledon   1995     ENG         0         3         0
# 17     Blackburn Rovers   1995     ENG         2         1         1
# 18          Aston Villa   1995     ENG         0         1         0
# 19     Blackburn Rovers   1995     ENG         2         1         1
#
#    HT Team 2 GGD Team 1 (pts) Team 2 (pts)     New_Date
# 0          0   2            3            0  19 Aug 1995
# 1          0   1            3            0  19 Aug 1995
# 2          0   0            1            1  19 Aug 1995
# 3          0   1            3            0  19 Aug 1995
# 4          1   0            1            1  19 Aug 1995
# 5          0   3            3            0  19 Aug 1995
# 6          3   1            0            3  19 Aug 1995
# 7          0   1            0            3  19 Aug 1995
# 8          2   1            3            0  19 Aug 1995
# 9          1   0            1            1  20 Aug 1995
# 10         0   1            3            0  21 Aug 1995
# 11         1   2            0            3  22 Aug 1995
# 12         0   1            3            0  23 Aug 1995
# 13         0   2            0            3  23 Aug 1995
# 14         0   1            3            0  23 Aug 1995
# 15         0   0            1            1  23 Aug 1995
# 16         1   3            0            3  23 Aug 1995
# 17         0   1            3            0  23 Aug 1995
# 18         0   1            0            3  23 Aug 1995
# 19         0   1            3            0  26 Aug 1995

# %%
#save dataframe cleaned
newDf.write.csv('sources/clean_BIG_FIVE_1995-2019.csv')

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
#
# ![title](img/Data_Model.png)
#
# #### 3.2 Mapping Out Data Pipelines
#
# - Create an Azure Blob Storage
# - Copy cleaned source files to Blob Storage
# - Create an Azure Data Factory
# - Create a SQL Database
# - Use the SQL query file (create_tables.sql) in order to create the tables database.
# - Using Data Factory, implement the ETL process from the files to Azure SQL Datawarehouse

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
# Write code here

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %%
# Perform quality checks here

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  * The database needed to be accessed by 100+ people.
